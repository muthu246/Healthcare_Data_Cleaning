# %%
import pandas as pd
import numpy as np

data = {
    'patient_id': [101,102,103,104,105,106,107,108,109,110,
                   111,112,113,114,115,101,107,118,119,120],
    'age': ['25','34',None,'45','29',None,'38','52','27','41',
            '33','unknown','48','26','35','25','38','31',None,'44'],
    'weight': ['70','65','80',None,'75',None,'68','90','72','85',
               '78',None,'82','69','N/A','70','68','74',None,'88'],
    'blood_pressure': [120,130,None,140,125,None,135,None,118,145,
                      128,None,138,122,None,120,135,126,None,142],
    'medication': ['Aspirin','Metformin','Lisinopril',None,'Aspirin',
                   'Metformin','Lisinopril','Aspirin',None,'Metformin',
                   'Lisinopril','Aspirin',None,'Metformin','Aspirin',
                   'Aspirin','Lisinopril','Metformin','Aspirin',None],
    'insurance_provider': ['Blue Cross','Aetna','Cigna','UnitedHealth',None,
                          'Blue Cross','Aetna','Cigna','UnitedHealth','Blue Cross',
                          'Aetna',None,'UnitedHealth','Blue Cross','Aetna',
                          'Blue Cross','Aetna','Cigna','UnitedHealth',None]
}

df = pd.DataFrame(data)
# Out:
#     patient_id      age weight  blood_pressure  medication insurance_provider
# 0          101       25     70           120.0     Aspirin         Blue Cross
# 1          102       34     65           130.0   Metformin              Aetna
# 2          103     None     80             NaN  Lisinopril              Cigna
# 3          104       45   None           140.0        None       UnitedHealth
# 4          105       29     75           125.0     Aspirin               None
# 5          106     None   None             NaN   Metformin         Blue Cross
# 6          107       38     68           135.0  Lisinopril              Aetna
# 7          108       52     90             NaN     Aspirin              Cigna
# 8          109       27     72           118.0        None       UnitedHealth
# 9          110       41     85           145.0   Metformin         Blue Cross
# 10         111       33     78           128.0  Lisinopril              Aetna
# 11         112  unknown   None             NaN     Aspirin               None
# 12         113       48     82           138.0        None       UnitedHealth
# 13         114       26     69           122.0   Metformin         Blue Cross
# 14         115       35    N/A             NaN     Aspirin              Aetna
# 15         101       25     70           120.0     Aspirin         Blue Cross
# 16         107       38     68           135.0  Lisinopril              Aetna
# 17         118       31     74           126.0   Metformin              Cigna
# 18         119     None   None             NaN     Aspirin       UnitedHealth
# 19         120       44     88           142.0        None               None

# %%
#Task 1 — Inspect the Data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          20 non-null     int64
#  1   age                 17 non-null     object
#  2   weight              16 non-null     object
#  3   blood_pressure      14 non-null     float64
#  4   medication          16 non-null     object
#  5   insurance_provider  17 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.1+ KB

# %%
df.isnull().sum()
# Out:
# patient_id            0
# age                   3
# weight                4
# blood_pressure        6
# medication            4
# insurance_provider    3
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# patient_id             0.0
# age                   15.0
# weight                20.0
# blood_pressure        30.0
# medication            20.0
# insurance_provider    15.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
#Task 2 — Data Type Conversion
df['age'] = pd.to_numeric(df['age'], errors='coerce')
df['weight'] = pd.to_numeric(df['weight'], errors='coerce')
df[['age','weight']].isnull().sum()
df['insurance_provider'] = df['insurance_provider'].astype('category')
df.dtypes
# Out:
# patient_id               int64
# age                    float64
# weight                 float64
# blood_pressure         float64
# medication              object
# insurance_provider    category
# dtype: object

# %%
#Task 3: Handle Missing Values
df['age'].fillna(df['age'].median(), inplace=True)
df['weight'].fillna(df['weight'].median(), inplace=True)
df['blood_pressure'].fillna(df['blood_pressure'].median(), inplace=True)
# Out:
# /tmp/ipykernel_319/85799672.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(), inplace=True)
# /tmp/ipykernel_319/85799672.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['weight'].fillna(df['weight'].median(), inplace=True)
# /tmp/ipykernel_319/85799672.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['blood_pressure'].fillna(df['blood_pressure'].median(), inplace=True)

# %%
df['medication'].fillna(df['medication'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_319/409894974.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['medication'].fillna(df['medication'].mode()[0], inplace=True)

# %%
df['insurance_provider'].fillna('Unknown', inplace=True)
# Out:
# /tmp/ipykernel_319/3182426868.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['insurance_provider'].fillna('Unknown', inplace=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_319/3182426868.py in <cell line: 0>()
# ----> 1 df['insurance_provider'].fillna('Unknown', inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    7347                     )
#    7348
# -> 7349                 new_data = self._mgr.fillna(
#    7350                     value=value, limit=limit, inplace=inplace, downcast=downcast
#    7351                 )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/base.py in fillna(self, value, limit, inplace, downcast)
#     184             limit = libalgos.validate_limit(None, limit=limit)
#     185
# --> 186         return self.apply_with_block(
#     187             "fillna",
#     188             value=value,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     361                 applied = b.apply(f, **kwargs)
#     362             else:
# --> 363                 applied = getattr(b, f)(**kwargs)
#     364             result_blocks = extend_blocks(applied, result_blocks)
#     365
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in fillna(self, value, limit, inplace, downcast, using_cow, already_warned)
#    2332                 # 3rd party EA that has not implemented copy keyword yet
#    2333                 refs = None
# -> 2334                 new_values = self.values.fillna(value=value, method=None, limit=limit)
#    2335                 # issue the warning *after* retrying, in case the TypeError
#    2336                 #  was caused by an invalid fill_value
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/_mixins.py in fillna(self, value, method, limit, copy)
#     370                 else:
#     371                     new_values = self[:]
# --> 372                 new_values[mask] = value
#     373         else:
#     374             # We validate the fill_value even if there is nothing to fill
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/_mixins.py in __setitem__(self, key, value)
#     259     def __setitem__(self, key, value) -> None:
#     260         key = check_array_indexer(self, key)
# --> 261         value = self._validate_setitem_value(value)
#     262         self._ndarray[key] = value
#     263
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/categorical.py in _validate_setitem_value(self, value)
#    1587             return self._validate_listlike(value)
#    1588         else:
# -> 1589             return self._validate_scalar(value)
#    1590
#    1591     def _validate_scalar(self, fill_value):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/categorical.py in _validate_scalar(self, fill_value)
#    1612             fill_value = self._unbox_scalar(fill_value)
#    1613         else:
# -> 1614             raise TypeError(
#    1615                 "Cannot setitem on a Categorical with a new "
#    1616                 f"category ({fill_value}), set the categories first"
#
# TypeError: Cannot setitem on a Categorical with a new category (Unknown), set the categories first

# %%
df.isnull().sum()
# Out:
# patient_id            0
# age                   0
# weight                0
# blood_pressure        0
# medication            0
# insurance_provider    3
# dtype: int64

# %%
#Task 4 — Handle Duplicates
df[df.duplicated(keep=False)]
# Out:
#     patient_id   age  weight  blood_pressure  medication insurance_provider
# 0          101  25.0    70.0           120.0     Aspirin         Blue Cross
# 6          107  38.0    68.0           135.0  Lisinopril              Aetna
# 15         101  25.0    70.0           120.0     Aspirin         Blue Cross
# 16         107  38.0    68.0           135.0  Lisinopril              Aetna

# %%
df[df.duplicated(subset=['patient_id'])]
# Out:
#     patient_id   age  weight  blood_pressure  medication insurance_provider
# 15         101  25.0    70.0           120.0     Aspirin         Blue Cross
# 16         107  38.0    68.0           135.0  Lisinopril              Aetna

# %%
print("Before:", df.shape)
# Out:
# Before: (20, 6)

# %%
df = df.drop_duplicates(subset=['patient_id'], keep='first')

# %%
print("After:", df.shape)
# Out:
# After: (18, 6)

# %%
#Task 5 — Complete Workflow with Verification
df_clean = df.copy()

# %%
print("Shape before:", df_clean.shape)
print("Missing before:\n", df_clean.isnull().sum())
print("Duplicates before:", df_clean.duplicated(subset=['patient_id']).sum())
print("Dtypes before:\n", df_clean.dtypes)
# Out:
# Shape before: (18, 6)
# Missing before:
#  patient_id            0
# age                   0
# weight                0
# blood_pressure        0
# medication            0
# insurance_provider    3
# dtype: int64
# Duplicates before: 0
# Dtypes before:
#  patient_id               int64
# age                    float64
# weight                 float64
# blood_pressure         float64
# medication              object
# insurance_provider    category
# dtype: object

# %%
df_clean['age'] = pd.to_numeric(df_clean['age'], errors='coerce')
df_clean['weight'] = pd.to_numeric(df_clean['weight'], errors='coerce')
df_clean['insurance_provider'] = df_clean['insurance_provider'].astype('category')

# %%
df_clean['age'].fillna(df_clean['age'].median(), inplace=True)
df_clean['weight'].fillna(df_clean['weight'].median(), inplace=True)
df_clean['blood_pressure'].fillna(df_clean['blood_pressure'].median(), inplace=True)
df_clean['medication'].fillna(df_clean['medication'].mode()[0], inplace=True)
df_clean['insurance_provider'].fillna('Unknown', inplace=True)
# Out:
# /tmp/ipykernel_319/3735712386.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['age'].fillna(df_clean['age'].median(), inplace=True)
# /tmp/ipykernel_319/3735712386.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['weight'].fillna(df_clean['weight'].median(), inplace=True)
# /tmp/ipykernel_319/3735712386.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['blood_pressure'].fillna(df_clean['blood_pressure'].median(), inplace=True)
# /tmp/ipykernel_319/3735712386.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['medication'].fillna(df_clean['medication'].mode()[0], inplace=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_319/3735712386.py in <cell line: 0>()
#       3 df_clean['blood_pressure'].fillna(df_clean['blood_pressure'].median(), inplace=True)
#       4 df_clean['medication'].fillna(df_clean['medication'].mode()[0], inplace=True)
# ----> 5 df_clean['insurance_provider'].fillna('Unknown', inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    7347                     )
#    7348
# -> 7349                 new_data = self._mgr.fillna(
#    7350                     value=value, limit=limit, inplace=inplace, downcast=downcast
#    7351                 )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/base.py in fillna(self, value, limit, inplace, downcast)
#     184             limit = libalgos.validate_limit(None, limit=limit)
#     185
# --> 186         return self.apply_with_block(
#     187             "fillna",
#     188             value=value,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     361                 applied = b.apply(f, **kwargs)
#     362             else:
# --> 363                 applied = getattr(b, f)(**kwargs)
#     364             result_blocks = extend_blocks(applied, result_blocks)
#     365
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in fillna(self, value, limit, inplace, downcast, using_cow, already_warned)
#    2332                 # 3rd party EA that has not implemented copy keyword yet
#    2333                 refs = None
# -> 2334                 new_values = self.values.fillna(value=value, method=None, limit=limit)
#    2335                 # issue the warning *after* retrying, in case the TypeError
#    2336                 #  was caused by an invalid fill_value
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/_mixins.py in fillna(self, value, method, limit, copy)
#     370                 else:
#     371                     new_values = self[:]
# --> 372                 new_values[mask] = value
#     373         else:
#     374             # We validate the fill_value even if there is nothing to fill
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/_mixins.py in __setitem__(self, key, value)
#     259     def __setitem__(self, key, value) -> None:
#     260         key = check_array_indexer(self, key)
# --> 261         value = self._validate_setitem_value(value)
#     262         self._ndarray[key] = value
#     263
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/categorical.py in _validate_setitem_value(self, value)
#    1587             return self._validate_listlike(value)
#    1588         else:
# -> 1589             return self._validate_scalar(value)
#    1590
#    1591     def _validate_scalar(self, fill_value):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/categorical.py in _validate_scalar(self, fill_value)
#    1612             fill_value = self._unbox_scalar(fill_value)
#    1613         else:
# -> 1614             raise TypeError(
#    1615                 "Cannot setitem on a Categorical with a new "
#    1616                 f"category ({fill_value}), set the categories first"
#
# TypeError: Cannot setitem on a Categorical with a new category (Unknown), set the categories first

# %%
df_clean = df_clean.drop_duplicates(subset=['patient_id'], keep='first')

# %%
print("\n----- VERIFICATION REPORT -----")

print("Shape after:", df_clean.shape)

print("\nMissing values after:")
print(df_clean.isnull().sum())

print("\nDuplicates after:")
print(df_clean.duplicated(subset=['patient_id']).sum())

print("\nData types after:")
print(df_clean.dtypes)
# Out:
# ----- VERIFICATION REPORT -----
# Shape after: (18, 6)
#
# Missing values after:
# patient_id            0
# age                   0
# weight                0
# blood_pressure        0
# medication            0
# insurance_provider    3
# dtype: int64
#
# Duplicates after:
# 0
#
# Data types after:
# patient_id               int64
# age                    float64
# weight                 float64
# blood_pressure         float64
# medication              object
# insurance_provider    category
# dtype: object
